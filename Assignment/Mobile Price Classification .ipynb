# %% [markdown]
# ## Mobile Price Classification

# %% [markdown]
# ## Step1: Data Gathering

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd

# %%
path = r"G:\Machine Learning\Projects\Assignment\Mobile Price Clasification\DataSet\train.csv"
df = pd.read_csv(path)
#pd.set_option("dispaly.max_columns"25)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# ## Step2: Perform basic data quality checks

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# Check the missing values
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ### There is no missing values in the dataset

# %%
# check the duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### There is no duplicated rows in the dataset

# %%
df = df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# ## Step3: Separate Data into X and Y feature
#     Y = 'price_range'
#     X = Remaining all the features

# %%
X = df.drop(columns='price_range')
Y = df[['price_range']]

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
Y.head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# ## Step4: Data Preprocessing and Data Cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
con =list(X.columns[X.dtypes != 'object'])

# %%
print(con)
# Out:
# ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']

# %%
pre = make_pipeline(
    SimpleImputer(strategy='median'),
    StandardScaler()
).set_output(transform='pandas')

# %%
pre
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
X_pre = pre.fit_transform(X)
X_pre.head()
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.902597 -0.990050     0.830779 -1.019184 -0.762495 -1.043966
# 1      -0.495139  1.010051    -1.253064  0.981177 -0.992890  0.957886
# 2      -1.537686  1.010051    -1.253064  0.981177 -0.532099  0.957886
# 3      -1.419319  1.010051     1.198517 -1.019184 -0.992890 -1.043966
# 4       1.325906  1.010051    -0.395011 -1.019184  2.002254  0.957886
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0   -1.380644  0.340740   1.349249 -1.101971 -1.305750  -1.408949 -1.146784
# 1    1.155024  0.687548  -0.120059 -0.664768 -0.645989   0.585778  1.704465
# 2    0.493546  1.381165   0.134244  0.209639 -0.645989   1.392684  1.074968
# 3   -1.215274  1.034357  -0.261339  0.646842 -0.151168   1.286750  1.236971
# 4    0.658915  0.340740   0.021220 -1.101971  0.673534   1.268718 -0.091452
#
#         ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# ...

# %% [markdown]
# ## Step5: Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.75,random_state=42)

# %%
xtrain.head()
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 1738      -1.656054 -0.990050    -0.762748  0.981177  2.463046  0.957886
# 548       -1.360135  1.010051    -0.517590 -1.019184 -0.992890  0.957886
# 936       -0.986821 -0.990050    -0.885327 -1.019184 -0.762495 -1.043966
# 1389       1.280380 -0.990050    -1.253064  0.981177  0.389484 -1.043966
# 1607      -1.125675 -0.990050     0.217884  0.981177 -0.992890  0.957886
#
#       int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# 1738   -0.443549  0.340740  -0.120059 -0.664768  1.333295  -0.626835
# 548    -1.380644  1.381165   1.462273 -1.539175 -1.140810  -0.514139
# 936     0.107683  0.340740  -1.476344  0.646842 -1.305750   1.390430
# 1389    1.099901  1.381165  -0.572154  0.646842  0.013773  -1.228634
# 1607    0.052560 -0.006069  -0.995993 -0.227564 -1.305750   1.367891
#
#       px_width       ram      sc_h      sc_w  talk_time   three_g  \
# ...

# %%
xtest.head()
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 1860       0.927552 -0.990050     1.198517 -1.019184 -0.301703  0.957886
# 353       -0.128653 -0.990050    -1.253064 -1.019184  0.619880  0.957886
# 1333       1.669628 -0.990050     1.688833 -1.019184  1.080671 -1.043966
# 905       -0.567980  1.010051     0.585621 -1.019184 -0.071307 -1.043966
# 1289      -1.419319  1.010051    -1.253064  0.981177  0.619880 -1.043966
#
#       int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# 1860   -0.388426  0.340740   1.688320 -1.101971 -0.810929  -0.978448
# 353    -1.325520 -0.006069  -0.063548  1.521249  1.003414  -0.834197
# 1333   -0.994781 -0.352878   1.575296  1.084046  1.333295  -0.793626
# 905    -0.829411 -1.046495   0.727618 -0.664768  1.498235  -0.877022
# 1289    1.430640 -0.006069  -0.289595  0.209639 -0.316108   0.847234
#
#       px_width       ram      sc_h      sc_w  talk_time   three_g  \
# ...

# %%
ytrain.head()
# Out:
#       price_range
# 1738            1
# 548             2
# 936             3
# 1389            0
# 1607            2

# %%
ytest.head()
# Out:
#       price_range
# 1860            0
# 353             2
# 1333            1
# 905             3
# 1289            1

# %% [markdown]
# ## Step6: Build the models

# %% [markdown]
# ## Step6.1: Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=3,
    min_samples_leaf=3,
    criterion='gini'
)

# %%
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=3, min_samples_split=3)

# %%
dtc.score(xtrain,ytrain)
# Out:
# 0.8753333333333333

# %%
dtc.score(xtest,ytest)
# Out:
# 0.794

# %% [markdown]
# ## Step7: Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth':[3,4,5,6,7,8,9,10],
    'min_samples_split':[1,2,3,4,5,6,7,8,9],
    'min_samples_leaf':[1,2,3,4,5,6,7,8,9],
    'criterion':['gini','entropy']
}

# %%
base_model = DecisionTreeClassifier()

# %%
gscv = GridSearchCV(estimator=base_model,param_grid=params,cv=4,scoring='f1_macro')
gscv.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_split': [1, 2, 3, 4, 5, 6, 7, 8, 9]},
#              scoring='f1_macro')

# %%
gscv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 9,
#  'min_samples_leaf': 3,
#  'min_samples_split': 3}

# %%
gscv.best_score_
# Out:
# np.float64(0.8661218115656073)

# %%
gscv.score(xtrain,ytrain)
# Out:
# 0.9721250825381873

# %%
best_dtc = gscv.best_estimator_
best_dtc
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=9, min_samples_leaf=3,
#                        min_samples_split=3)

# %% [markdown]
# ## Step8: Evaluation Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(best_dtc,xtest,ytest)

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report
ypred_test = best_dtc.predict(xtest)
ypred_test[:5]
# Out:
# array([0, 2, 1, 3, 1])

# %%
print(classification_report(ytest,ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       132
#            1       0.81      0.86      0.84       118
#            2       0.80      0.78      0.79       120
#            3       0.89      0.87      0.88       130
#
#     accuracy                           0.86       500
#    macro avg       0.86      0.86      0.86       500
# weighted avg       0.86      0.86      0.86       500

# %% [markdown]
# ## Step9: Importance Feature

# %%
best_dtc.feature_importances_
# Out:
# array([1.24747454e-01, 0.00000000e+00, 1.70196440e-04, 0.00000000e+00,
#        1.52424615e-03, 0.00000000e+00, 2.39436231e-03, 5.17740440e-03,
#        6.72024538e-03, 2.24078189e-03, 3.14006793e-03, 7.24613563e-02,
#        7.74434490e-02, 6.98113671e-01, 0.00000000e+00, 1.70196440e-04,
#        5.69656891e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
imp_features_bymodel = pd.Series(best_dtc.feature_importances_,index=fea_names)
imp_features_bymodel.sort_values(ascending=False)
# Out:
# ram              0.698114
# battery_power    0.124747
# px_width         0.077443
# px_height        0.072461
# mobile_wt        0.006720
# talk_time        0.005697
# m_dep            0.005177
# pc               0.003140
# int_memory       0.002394
# n_cores          0.002241
# fc               0.001524
# clock_speed      0.000170
# sc_w             0.000170
# blue             0.000000
# dual_sim         0.000000
# four_g           0.000000
# sc_h             0.000000
# three_g          0.000000
# touch_screen     0.000000
# wifi             0.000000
# dtype: float64

# %% [markdown]
# ## Above model is provideing score is 0.80, we can consider this model for final model building and use it for out of sample predictions

# %% [markdown]
# ## Step10: Out of Sample Prediction

# %%
path2 = r"G:\Machine Learning\Projects\Assignment\Mobile Price Clasification\DataSet\test.csv"
df2 = pd.read_csv(path2)
df2.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df2.shape
# Out:
# (1000, 21)

# %%
df2 = df2.drop('id',axis=1)

# %%
df2.shape
# Out:
# (1000, 20)

# %%
pre
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
df2_pre = pre.transform(df2)
df2_pre.head()
# Out:
#    battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0      -0.445060  1.010051     0.340463  0.981177  2.232650 -1.043966
# 1      -0.904874  1.010051    -1.253064  0.981177 -0.071307  0.957886
# 2       1.294038  1.010051     1.566254 -1.019184 -0.762495 -1.043966
# 3       0.699922 -0.990050    -1.253064  0.981177  3.154233  0.957886
# 4       0.444976 -0.990050    -0.149853 -1.019184  1.541463  0.957886
#
#    int_memory     m_dep  mobile_wt   n_cores        pc  px_height  px_width  \
# 0   -1.490890 -1.393304   1.490528 -0.664768  1.003414  -0.944639  0.371413
# 1    1.596010  1.034357   1.434017  0.209639  0.343653   0.227403 -0.913037
# 2   -0.278179  1.381165   1.292737 -0.664768 -0.975869   1.408462  0.264954
# 3   -0.388426 -0.006069  -1.250297  1.521249  1.663176  -0.789118  1.158284
# 4    0.934531 -0.006069  -0.911225  0.646842  1.333295   0.234165 -1.021810
#
#         ram      sc_h      sc_w  talk_time   three_g  touch_screen      wifi
# ...

# %%
price_predicted = best_dtc.predict(df2_pre)

# %%
price_predicted[:10]
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0])

# %%
df2['price_predicted'] = price_predicted

# %%
df2.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  ...        226      1412  3476    12     7          2
# 1        191        5  ...        746       857  3895     6     0          7
# 2        186        3  ...       1270      1366  2396    17    10         10
# 3         96        8  ...        295      1752  3893    10     0          7
# 4        108        6  ...        749       810  1773    15     8          7
#
# ...

# %% [markdown]
# ## Step11: Save the result to csv file

# %%
df2.to_csv('Price Results.csv',index=False)
